# %% [markdown]
# ## LAB NLP PART 1 (SAT 7 FEB 2025)

# %%
# Corpora -> Sejumlah teks besar yang akan diproses

# %%
# nltk -> natural language toolkot
# tokenizing -> memisahkan teks yang besar menjadi lebih kecil

import nltk
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize, sent_tokenize
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
sentence = "I scream, you scream, we all scream for ice cream"

word_list = word_tokenize(sentence)
print(word_list)
# Out:
# ['I', 'scream', ',', 'you', 'scream', ',', 'we', 'all', 'scream', 'for', 'ice', 'cream']

# %%
paragraph = "Slippery snakes slither silently. Swift sparrows spot subtle shifts. Brisk beetles bump blue berries. Clever crabs cross crowded cobblestones. Thin thrushes trill through thickets."

sentence_list = sent_tokenize(paragraph)

print(sentence_list)
# Out:
# ['Slippery snakes slither silently.', 'Swift sparrows spot subtle shifts.', 'Brisk beetles bump blue berries.', 'Clever crabs cross crowded cobblestones.', 'Thin thrushes trill through thickets.']

# %% [markdown]
# # STOPWORDS

# %%
# Stopwords -> Sekumpulan kata umum yang valuenya ga terlalu kepake

from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
eng_stopwords = stopwords.words('english')
print(eng_stopwords)
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %%
removed_stopwords = []

# Pake Looping
for word in word_list:
  if word.lower(

  ) not in eng_stopwords:
    removed_stopwords.append(word)

print(removed_stopwords)
print(word_list)
# Out:
# ['scream', ',', 'scream', ',', 'scream', 'ice', 'cream']
# ['I', 'scream', ',', 'you', 'scream', ',', 'we', 'all', 'scream', 'for', 'ice', 'cream']

# %%
# Pake List Comprehension

removed_stopwords2 = [word for word in word_list if word.lower() not in eng_stopwords]
print(removed_stopwords2)
# Out:
# ['scream', ',', 'scream', ',', 'scream', 'ice', 'cream']

# %% [markdown]
# # REMOVED PUNCTUATION (hapus tanda baca)

# %%
import string

punctuation = string.punctuation
print(punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
removed_punctuation = [token for token in removed_stopwords if token not in punctuation]
print(removed_punctuation)

print(removed_punctuation)
# Out:
# ['scream', 'scream', 'scream', 'ice', 'cream']
# ['scream', 'scream', 'scream', 'ice', 'cream']

# %% [markdown]
# # REMOVED NUMBER

# %%
# CLEANING NLP
# Stopwords
# Punctuation
# Angka

tes = ['123s','2','hai']
# isalpha()
result = [t for t in tes if t.isalpha()]
print(result)
# Out:
# ['hai']
