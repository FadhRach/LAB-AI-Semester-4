# %% [markdown]
# ## LAB NLP PART 3 (SAT 21 FEB 2025)

# %% [markdown]
# Course Outline
# - [] POS(Part Of Speech) Tagging -> Jenis kata homofon / homograf
# - [] Frequency Distribution
# - [] Context-Free Grammar (CFG)

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('words')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.tag import pos_tag # From treebank postag
from nltk.probability import FreqDist
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.

# %%
sentence = "Betty bough a bit of better butter ro make her bitter batter better, but the better Betty bought made her batter bitterer than before"
sentence2 = "Tom told Tim to take ten tiny turtles to the tall tower, but Tim tumbled twice trying to transport the tricky turtles"

eng_stopwords = stopwords.words('english')
punctuation = string.punctuation

word_list = word_tokenize(sentence)
removed_stopwords = [token for token in word_list if token.lower() not in eng_stopwords]
removed_punctuation = [token for token in removed_stopwords if token not in punctuation]

print(removed_punctuation)
# Out:
# ['Betty', 'bough', 'bit', 'better', 'butter', 'ro', 'make', 'bitter', 'batter', 'better', 'better', 'Betty', 'bought', 'made', 'batter', 'bitterer']

# %%
tagged = pos_tag(removed_punctuation)
print(tagged)
# Out:
# [('Betty', 'NNP'), ('bough', 'JJ'), ('bit', 'NN'), ('better', 'RBR'), ('butter', 'NN'), ('ro', 'NNS'), ('make', 'VBP'), ('bitter', 'JJ'), ('batter', 'NN'), ('better', 'RBR'), ('better', 'JJR'), ('Betty', 'NNP'), ('bought', 'VBD'), ('made', 'VBN'), ('batter', 'NN'), ('bitterer', 'NN')]

# %%
from nltk.chunk import ne_chunk
nltk.download('maxent_ne_chunker_tab')

ner = ne_chunk(tagged)
print(ner)
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# (S
#   (GPE Betty/NNP)
#   bough/JJ
#   bit/NN
#   better/RBR
#   butter/NN
#   ro/NNS
#   make/VBP
#   bitter/JJ
#   batter/NN
#   better/RBR
#   better/JJR
#   (PERSON Betty/NNP)
#   bought/VBD
#   made/VBN
#   batter/NN
#   bitterer/NN)

# %%
from nltk.probability import FreqDist

fd = FreqDist(word_tokenize(sentence2))

for word, count in fd.most_common(10):
    print(f"{word}: {count}")
# Out:
# to: 3
# Tim: 2
# turtles: 2
# the: 2
# Tom: 1
# told: 1
# take: 1
# ten: 1
# tiny: 1
# tall: 1

# %%
# Context-Free Grammar

from nltk import CFG
from nltk.parse import ChartParser
from nltk.tokenize import word_tokenize
